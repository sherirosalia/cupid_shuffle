# %%
# %pip install nltk

# %%
# !pip install -U yellowbrick

# %%
import sys
import pandas as pd
import re
import nltk
from operator import add
from pyspark.sql import SparkSession
from pyspark.ml.feature import StopWordsRemover
import pyspark.sql.functions as f
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType
# from nltk.corpus import stopwords

# %%
spark = SparkSession\
  .builder \
  .appName("PythonWordCount") \
  .getOrCreate()


# # Read CSV from OVHcloud Object Storage https://github.com/walkerkq/musiclyrics
# data = spark.read.format('json').options(header='true', inferSchema='true') \
#   .load('hip_hop_lyrics.json', sep=",", header=True) \

data = spark.read.option("multiline","true").json('hipHop_romance_lyrics.json')
data.select("Lyrics").show()
print('############ JSON extract:')
data.show()
# Out:
# +--------------------+
# |              Lyrics|
# +--------------------+
# |Ah, skru' op for ...|
# |[Queen Heroin]
# As...|
# |Tell the DJ Turn ...|
# |[Verse 1: Yowda]
# ...|
# |        INSTRUMENTAL|
# |Host: Anna Baccia...|
# |[Produced by Rash...|
# |[Vers 1: Node]
# So...|
# |[Produced by DJ M...|
# |[Verse 1: Dr. Dre...|
# |[Intro: 2Pac]
# Big...|
# |Tsunami, drop!
# Dr...|
# |4/1
# Ariana Grande...|
# |[Chorus: Lloyd Ba...|
# |[Letra de "Gasoli...|
# |[Intro]
# Shake dat...|
# |Mein kopf der spe...|
# |3/2
# Deko - Moonki...|
# |Return to clone m...|
# |Emergency call th...|
# +--------------------+
# only showing top 20 rows
#
# ############ JSON extract:
# +--------------------+--------------------+--------------------+
# |              Artist|              Lyrics|               Title|
# +--------------------+--------------------+--------------------+
# |              Marwan|Ah, skru' op for ...|        ButterBombay|
# |     Various Artists|[Queen Heroin]
# As...|             Jumanji|
# |         Yellow Claw|Tell the DJ Turn ...|       DJ Turn It Up|
# |               Yowda|[Verse 1: Yowda]
# ...|Shut Up (feat. Y.G.)|
# |       Joel Fletcher|        INSTRUMENTAL|           Afterdark|
# |The Notorious B.I.G.|Host: Anna Baccia...|Warning - 2005 Re...|
# |                 Nas|[Produced by Rash...|If I Ruled the Wo...|
# |                NODE|[Vers 1: Node]
# So...|          De Snakker|
# |                Tyga|[Produced by DJ M...|           Rack City|
# |             Dr. Dre|[Verse 1: Dr. Dre...|    Forgot About Dre|
# |                2Pac|[Intro: 2Pac]
# Big...|      All Eyez On Me|
# |               DVBBS|Tsunami, drop!
# Dr...|Tsunami - Radio Edit|
# |       Martin Garrix|4/1
# Ariana Grande...|Animals - Origina...|
# |         Lloyd Banks|[Chorus: Lloyd Ba...|Beamer, Benz or B...|
# |        Daddy Yankee|[Letra de "Gasoli...|            Gasolina|
# |           Sean Paul|[Intro]
# Shake dat...|            Get Busy|
# |           Die Atzen|Mein kopf der spe...|Disco Pogo - Atze...|
# |     Various Artists|3/2
# Deko - Moonki...|Skub Til Taget - ...|
# |      Fedde Le Grand|Return to clone m...|Put Your Hands Up...|
# |           Dada Life|Emergency call th...|Kick Out The Epic...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Tokenize DataFrame
data = Tokenizer(inputCol="Lyrics", outputCol="Words")

# %%
df=pd.read_json ('hipHop_romance_lyrics.json',)

# %%
df.Lyrics=df.Lyrics.replace('\n', ' ')


df.head()
# Out:
#                   Title           Artist  \
# 0          ButterBombay           Marwan
# 1               Jumanji  Various Artists
# 2         DJ Turn It Up      Yellow Claw
# 3  Shut Up (feat. Y.G.)            Yowda
# 4             Afterdark    Joel Fletcher
#
#                                               Lyrics
# 0  Ah, skru' op for lortet mayn\nYeah\nVi' ind' i...
# 1  [Queen Heroin]\nAsides from gettin in you, the...
# 2  Tell the DJ Turn It Up\nTell the DJ bring it b...
# 3  [Verse 1: Yowda]\nYou ain't talk about money ,...
# 4                                       INSTRUMENTAL

# %%
df.Lyrics=df.Lyrics.str.lower()

df.head()
# Out:
#                   Title           Artist  \
# 0          ButterBombay           Marwan
# 1               Jumanji  Various Artists
# 2         DJ Turn It Up      Yellow Claw
# 3  Shut Up (feat. Y.G.)            Yowda
# 4             Afterdark    Joel Fletcher
#
#                                               Lyrics
# 0  ah, skru' op for lortet mayn\nyeah\nvi' ind' i...
# 1  [queen heroin]\nasides from gettin in you, the...
# 2  tell the dj turn it up\ntell the dj bring it b...
# 3  [verse 1: yowda]\nyou ain't talk about money ,...
# 4                                       instrumental

# %%
s = '[verse 1]\n'
# df.Lyrics=df.Lyrics.lstrip('[verse 1]\n')
df.Lyrics=df.Lyrics.map(lambda x: x.lstrip(s))

# %%
import nltk
from nltk.corpus import stopwords
# print(stopwords.words('english'))

# %%
df.Lyrics=df.Lyrics.apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))

# %%
def identify_tokens(row):
    review = row['Lyrics']
    tokens = nltk.word_tokenize(review)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

df['Lyrics'] = df.apply(identify_tokens, axis=1)

# %%
stops = set(stopwords.words("english"))                  

def remove_stops(row):
    my_list = row['Lyrics']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)



df['Lyrics'] = df.apply(remove_stops, axis=1)

# %%
stops = set(['chorus', 'verse', 'de', 'na', 'ne', 'wan'])                 

def remove_stops(row):
    my_list = row['Lyrics']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)



df['Lyrics'] = df.apply(remove_stops, axis=1)

# %%
# Let's evaluate the POS tags for our test set data
tagged_stanzas_test = []
tagged_test = []

for word in df['Lyrics']:
  tagged_word = nltk.pos_tag(word)
  tagged_stanzas_test.append(tagged_word)

# This format is needed for below visualizer as in takes only two values. If you skip this format, it might give you - "too many values to unpack error" 
tagged_test.append(tagged_stanzas_test)

# %%
# Let's evaluate the POS tags for our train set data
tagged_stanzas_train = []
tagged_train = []

for word in df['Lyrics']:
  tagged_word = nltk.pos_tag(word)
  tagged_stanzas_train.append(tagged_word)

# This format is needed for below visualizer as in takes only two values. If you skip this format, it might give you - "too many values to unpack error" 
tagged_train.append(tagged_stanzas_train)

# %%
from yellowbrick.text import PosTagVisualizer
# %matplotlib inline
from matplotlib import pyplot as plt
from yellowbrick.style.palettes import PALETTES, SEQUENCES, color_palette
from yellowbrick.style import set_palette

# %%
set_palette('flatui')
plt.figure(figsize=(10,10))
viz = PosTagVisualizer()
viz.fit(tagged_train)
viz.show()

# %%
# df['Lyrics'] = df['Lyrics'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# df.Lyrics.head()

# %%
import seaborn as sns
from collections import  Counter

def plot_top_non_stopwords_barchart(text):
    stop=set(stopwords.words('english'))
    
    # new= text.str.split()
    new=text
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    counter=Counter(corpus)
    most=counter.most_common()
    x, y=[], []
    for word,count in most[:50]:
        if (word not in stop):
            x.append(word)
            y.append(count)
    plt.figure(figsize=(10,10))
    # sns.set_theme(style="whitegrid")
    # sns.color_palette("viridis")
    sns.barplot(x=y,y=x, palette="deep")

# %%
plot_top_non_stopwords_barchart(df['Lyrics'])

# %%
df.Lyrics.to_csv(
    'hip_hop.csv', index=True
)

# %%
data = spark.read.format('csv').options(header='true', inferSchema='true') \
  .load('hip_hop.csv') \

# %%
data.show()
# Out:
# +---+--------------------+
# |_c0|              Lyrics|
# +---+--------------------+
# |  0|['ah', 'skru', 'o...|
# |  1|['queen', 'heroin...|
# |  2|['tell', 'dj', 't...|
# |  3|['yowda', 'ai', '...|
# |  4|    ['instrumental']|
# |  5|['host', 'anna', ...|
# |  6|['produced', 'ras...|
# |  7|['node', 'som', '...|
# |  8|['produced', 'dj'...|
# |  9|['dr', 'dre', 'kn...|
# | 10|['intro', 'big', ...|
# | 11|['tsunami', 'drop...|
# | 12|['ariana', 'grand...|
# | 13|['lloyd', 'banks'...|
# | 14|['letra', 'gasoli...|
# | 15|['intro', 'shake'...|
# | 16|['mein', 'kopf', ...|
# | 17|['deko', 'moonkid...|
# | 18|['turn', 'clone',...|
# | 19|['mergency', 'cal...|
# +---+--------------------+
# only showing top 20 rows

# %%
data.withColumn('word', f.explode(f.split(f.col('Lyrics'), ' '))) \
  .groupBy('word') \
  .count() \
  .sort('count', ascending=False) \
  .show()
# Out:
# +--------+-----+
# |    word|count|
# +--------+-----+
# | 'like',| 2253|
# | 'know',| 2197|
# | 'love',| 2180|
# |  'got',| 1614|
# |  'one',| 1388|
# |   'oh',| 1339|
# | 'yeah',| 1332|
# | 'baby',| 1239|
# | 'feat',| 1199|
# |  'get',| 1194|
# |   'go',| 1048|
# | 'girl',| 1045|
# | 'time',| 1007|
# |  'see',|  978|
# |  'let',|  971|
# | 'back',|  903|
# | 'want',|  870|
# |'never',|  862|
# | 'make',|  836|
# |  'say',|  795|
# +--------+-----+
# only showing top 20 rows
